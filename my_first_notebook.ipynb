# %%
import sys
print(sys.executable)
# Out:
# c:\Users\saira\Documents\email_intelligence_engine\myvenv\Scripts\python.exe

# %%
# --- Company Persona ---
# Company Name: OrbitAI
# Product: "Starlight Platform", an AI-powered market analytics tool.
# Mission: To make data science accessible to all businesses.

# %%
import os

# Create the 'knowledge_base' directory if it doesn't already exist
os.makedirs('knowledge_base', exist_ok=True)

print("Folder 'knowledge_base' is ready.")
# Out:
# Folder 'knowledge_base' is ready.

# %%
# Paste the text I generate inside the triple quotes
project_nova_brief = """
Project Brief: Project Nova
Company: OrbitAI
Date: August 20, 2025
Project Sponsor: Head of Product

## 1. Project Summary
Project Nova is a strategic initiative to design, develop, and integrate a new customer sentiment analysis feature into our flagship 'Starlight Platform'. This feature will automatically analyze customer feedback from various sources (e.g., support tickets, reviews, surveys) to classify sentiment as positive, negative, or neutral. The insights will be displayed in a new, interactive dashboard, empowering our clients to better understand customer satisfaction, identify trends, and make data-driven decisions to improve their products and services.

## 2. Objectives
Develop a high-accuracy sentiment analysis model: Deliver a machine learning model capable of classifying text-based customer feedback with an accuracy of over 85% on our internal benchmarks.

Seamlessly integrate with the Starlight Platform: Natively embed the sentiment analysis results into the existing platform, ensuring a consistent and intuitive user experience. This includes creating a new, dedicated analytics dashboard.

Provide actionable insights: The new feature must empower users to not only view sentiment scores but also to drill down into key topics and trends, helping them identify specific drivers of customer satisfaction and dissatisfaction.

Launch by Q1 2026: Complete development, testing, and deployment to all Starlight Platform users by the end of Q1 2026.

## 3. Key       Stakeholders
Role	        Name / Department	        Responsibilities
Project         Manager	Sarah Chen	        Manages project timeline, resources, and communication.
Lead            Developer	David Rodriguez	Oversees model development and backend integration.
UX Designer	    Emily White	                Designs the sentiment analysis dashboard and user interface.
Product Team    Product Dept.	            Defines feature requirements and ensures alignment with business goals.
Marketing Team	Marketing Dept.	        Prepares launch materials and user-facing documentation.

Export to Sheets
## 4. Timeline
The project is broken down into five key phases with the following estimated schedule:

Phase 1: Research & Planning (Aug 25, 2025 - Sep 5, 2025)

Finalize technical requirements.

Gather and preprocess initial training data.

Select the core machine learning model architecture.

Phase 2: Model Development & Training (Sep 8, 2025 - Oct 17, 2025)

Train and validate the first version of the sentiment model.

Iterate on the model to improve accuracy.

Phase 3: Backend Integration (Oct 20, 2025 - Nov 14, 2025)

Develop the API to serve model predictions.

Integrate the API with the Starlight Platform's data ingestion pipeline.

Phase 4: Frontend & Dashboard Development (Nov 17, 2025 - Jan 9, 2026)

Build the interactive dashboard based on UX designs.

Connect the frontend to the backend API.

Phase 5: Testing & Deployment (Jan 12, 2026 - Feb 13, 2026)

Conduct end-to-end quality assurance (QA) testing.

Perform a beta launch with select customers.

Full production launch.

## 5. Risks
Risk	Likelihood	Impact	Mitigation Strategy
Model accuracy is below target	Medium	High	Allocate additional time for data cleaning and feature engineering. Explore alternative pre-trained models if initial results are poor.
Lack of sufficient training data	Medium	High	Work with the product team to source additional customer feedback data. Use data augmentation techniques to expand the dataset.
Poor user adoption	Low	Medium	Involve the UX Designer in early-stage development and conduct usability testing with a sample of clients before the beta launch.
Delay in a key phase	Medium	Medium	The Project Manager will hold weekly check-ins to monitor progress against the timeline and identify potential blockers early.
"""

# Save the text to a file
file_path = 'knowledge_base/project_nova_brief.txt'
with open(file_path, 'w') as f:
    f.write(project_nova_brief)

print(f"File '{file_path}' saved successfully.")
# Out:
# File 'knowledge_base/project_nova_brief.txt' saved successfully.

# %%
# Paste the text I generate inside the triple quotes
project_nova_brief = """
Starlight Platform API - Frequently Asked Questions (FAQ)
Last Updated: August 20, 2025

Welcome to the Starlight Platform API! This document provides answers to common questions to help you get started with your integration.

1. How do I get an API key to authenticate my requests?
To get your API key, you must first log in to your Starlight Platform account. Navigate to the Admin Dashboard, then click on the "API & Integrations" tab. In this section, you will find a button labeled "Generate New API Key." Your key will be a long string starting with sk_....

Remember to treat your API key like a password and keep it secure. You must include this key in the header of every request for authentication, like so:
Authorization: Bearer sk_your_api_key

2. Are there any rate limits I should be aware of?
Yes. To ensure fair usage and system stability for all our clients, the Starlight Platform API is rate-limited. By default, your account is limited to 100 requests per minute.

If you exceed this limit, you will receive a 429 Too Many Requests HTTP status code. We recommend implementing a retry mechanism with exponential backoff in your application to handle these cases gracefully. If you require a higher rate limit for your application, please contact our support team to discuss your use case.

3. What is the data format for API responses?
All data returned by the Starlight Platform API is in JSON (JavaScript Object Notation) format. Successful responses will always have a 200 OK HTTP status code and a body containing the requested data.

A typical successful response structure will look like this:

JSON

{
  "status": "success",

  "data": {
    "report_id": "rpt_12345",
    "results": [...]
  },
  "pagination": {
    "next_page_token": "token_abcde"
  }
}
4. How should I handle API errors?
The API uses standard HTTP status codes to indicate the success or failure of a request. You should build your integration to handle the following common error codes:

400 Bad Request: Your request was malformed. This could be due to a missing required parameter or an invalid value. The response body will contain a message field with more details.

401 Unauthorized: Your API key is missing, invalid, or expired.

404 Not Found: The resource you requested does not exist.

500 Internal Server Error: An unexpected error occurred on our end. Please wait a moment and try your request again. If the problem persists, check our status page or contact support.

5. Can you provide a simple example of fetching a report?
Certainly. To fetch a basic analytics report, you would make a GET request to the /reports endpoint. You can use a tool like curl to test this from your command line.

Here is an example that fetches a report with the ID rpt_12345:

Bash

curl -X GET "https://api.starlight-orbitai.com/v1/reports/rpt_12345" \
     -H "Authorization: Bearer sk_your_api_key"
This will return the full JSON payload for that specific report, which you can then parse and use in your application.

"""

# Save the text to a file
file_path = 'knowledge_base/starlight_api_faq.txt'
with open(file_path, 'w') as f:
    f.write(project_nova_brief)

print(f"File '{file_path}' saved successfully.")
# Out:
# File 'knowledge_base/starlight_api_faq.txt' saved successfully.

# %%
# Paste the text I generate inside the triple quotes
project_nova_brief = """
OrbitAI Internal Communication Policy
Our Goal: At OrbitAI, we believe in open, efficient, and respectful communication. This document isn't about strict rules; it's a guide to help us collaborate effectively as we grow. Our goal is to keep everyone informed without creating unnecessary noise.

## Slack: The Digital Office
Slack is our primary tool for real-time conversations, quick questions, and team collaboration.

Use Public Channels First: Default to public channels for work-related discussions. This keeps information transparent and allows others to learn or contribute.

Threads are Your Friend: For any conversation that involves more than two replies, please start a thread. This keeps our main channels clean and easy to scan.

Respect Focus Time: Use @here and @channel sparingly, as they notify everyone in the channel. Only use them for truly urgent and important announcements.

Set Your Status: Use statuses (e.g., 🗓️ In a meeting, 🌴 On vacation) to let others know your availability.

## Email: For Official Business
Email is for more formal, external communication or important internal announcements that need a permanent record.

Be Clear and Concise: Use a descriptive subject line (e.g., "Project Nova: Weekly Update"). Keep the body of the email focused and to the point.

Know Who to CC: Be mindful of who you include in an email chain. If someone's input is no longer needed, consider moving them to BCC or removing them from the thread.

Response Time: Aim to acknowledge important emails within 24 hours, even if it's just to say, "Got it, I'll look into this and get back to you by Friday."

## Meetings: For Collaboration
Meetings are for collaborative work, decision-making, and discussions that are too complex for Slack or email.

Have a Clear Agenda: Every meeting invitation must include a clear agenda with the topics to be discussed and the desired outcome.

Be on Time: Respect everyone's time by joining meetings promptly.

Come Prepared: Review the agenda and any pre-reading materials before the meeting starts.

30-Minute Default: Try to schedule meetings for 30 minutes by default. If more time is needed, be sure the agenda justifies it.

In short: Be thoughtful, be respectful, and choose the right tool for the job. Let's build something amazing together!
"""

# Save the text to a file
file_path = 'knowledge_base/common_policy.txt'
with open(file_path, 'w',encoding='utf-8') as f:
    f.write(project_nova_brief,)

print(f"File '{file_path}' saved successfully.")
# Out:
# File 'knowledge_base/common_policy.txt' saved successfully.

# %%
project_nova_brief = """
Of course. Here are the team roles and responsibilities for Project Nova.

Project Nova: Team Roles & Responsibilities
Document Purpose: This document outlines the primary roles and key responsibilities for the core team members assigned to Project Nova. The goal is to ensure clear ownership and smooth collaboration throughout the project lifecycle.

## Core Team
1. Project Manager
Team Member: Sarah Chen

Core Responsibility: To ensure Project Nova is delivered on time, within scope, and on budget. Sarah is the central point of contact for all project-related communication and coordination.

Key Responsibilities:

Develop and maintain the detailed project plan and timeline.

Organize and lead all project meetings (e.g., stand-ups, stakeholder reviews).

Track progress, identify potential blockers, and manage project risks.

Facilitate communication between the development team and other stakeholders.

Provide regular status updates to the Head of Product and other key stakeholders.

2. Lead Developer
Team Member: David Rodriguez

Core Responsibility: To oversee the technical architecture and implementation of the sentiment analysis feature. David is responsible for the quality, performance, and scalability of the code.

Key Responsibilities:

Lead the design of the backend system, including the machine learning model integration and API development.

Write high-quality, well-tested code for the core components of the feature.

Conduct code reviews for other developers contributing to the project.

Mentor junior developers and provide technical guidance.

Collaborate with the UX Designer to ensure the backend can support the required frontend functionality.

3. UX Designer
Team Member: Emily White

Core Responsibility: To design an intuitive, engaging, and user-friendly interface for the new sentiment analysis dashboard within the Starlight Platform.

Key Responsibilities:

Conduct user research to understand client needs and pain points related to sentiment analysis.

Create wireframes, mockups, and interactive prototypes for the new dashboard.

Develop and maintain the user flow and information architecture.

Collaborate closely with the Lead Developer to ensure technical feasibility of the designs.

Conduct usability testing sessions with beta customers to gather feedback and iterate on the design.
"""

# Save the text to a file
file_path = 'knowledge_base/team_roles_responsibilities.txt'
with open(file_path, 'w') as f:
    f.write(project_nova_brief)

print(f"File '{file_path}' saved successfully.")
# Out:
# File 'knowledge_base/team_roles_responsibilities.txt' saved successfully.

# %%
# Paste the entire JSON array I generate inside the triple quotes
training_data_json = """
[
  {
    "email_text": "Subject: Inquiry about Starlight Platform Pricing\n\nHi Team,\n\nCould you please provide me with the pricing details for your Starlight Platform? We are a mid-sized e-commerce company and are interested in the enterprise tier. A feature comparison sheet would also be helpful.\n\nThanks,\nJohn Doe",
    "intent": "Sales Inquiry",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: URGENT: API Gateway is Down!\n\nHello Support,\n\nOur integration with your Starlight API has completely stopped working as of 10:30 AM CDT. We are receiving 503 Service Unavailable errors on all endpoints. This is a critical production issue for us. Please advise immediately.\n\nBest,\nJane Smith, Lead Engineer",
    "intent": "Technical Support",
    "urgency": "High"
  },
  {
    "email_text": "Subject: Request for a Demo\n\nHi OrbitAI Sales,\n\nI saw your platform at the TechCrunch conference and was very impressed. Would it be possible to schedule a 30-minute demo for my team next week?\n\nRegards,\nAlex Johnson",
    "intent": "Sales Inquiry",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Quick Question: Project Nova Sync\n\nHi Sarah,\n\nCan we find 15 minutes tomorrow to sync up on the Project Nova timeline? I have a few questions about the Q4 deliverables.\n\nThanks,\nEmily",
    "intent": "Meeting Request",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Company Update: Welcome Our New Hires!\n\nHi Team,\n\nPlease join me in giving a warm welcome to our two new software engineers, Michael and Chloe, who are starting with us today! They will be joining the Starlight Platform team.\n\nBest,\nHR Department",
    "intent": "Internal Update",
    "urgency": "Low"
  },
  {
    "email_text": "Subject: Minor Bug Report: Dashboard Date Filter\n\nHi Support,\n\nI've noticed a small bug in the analytics dashboard. When I filter by 'Last 90 Days', the chart doesn't seem to update correctly. It's not urgent, but I wanted to make you aware.\n\nThanks,\nPeter",
    "intent": "Technical Support",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Urgent Meeting Request: Q3 Budget Review - EOD Deadline\n\nHi Finance Team,\n\nI need to schedule an urgent 30-minute meeting to finalize the Q3 budget report. This needs to be submitted by EOD today. Please let me know your availability ASAP.\n\nThanks,\nDirector of Operations",
    "intent": "Meeting Request",
    "urgency": "High"
  },
  {
    "email_text": "Subject: Partnership Opportunity\n\nHello OrbitAI,\n\nWe are a data visualization company and see a lot of synergy between our products. We would love to explore a potential partnership. Who would be the best person to speak with about this?\n\nSincerely,\nMaria Garcia",
    "intent": "Sales Inquiry",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Project Nova - Weekly Status Update\n\nHi Stakeholders,\n\nThis week, the Project Nova team completed the initial data gathering phase ahead of schedule. We are now moving into model architecture selection. No blockers to report.\n\nBest,\nSarah Chen",
    "intent": "Internal Update",
    "urgency": "Low"
  },
  {
    "email_text": "Subject: CRITICAL SYSTEM ALERT: Data Ingestion Pipeline Failure\n\nStarlight Support,\n\nOur primary data ingestion pipeline has failed. No new data has been processed in the last 2 hours. This is a severity-1 issue. We need immediate assistance.\n\nRegards,\nSystem Admin",
    "intent": "Technical Support",
    "urgency": "High"
  },
  {
    "email_text": "Subject: Follow-up on our call\n\nHi David,\n\nGreat chatting with you earlier. As discussed, can we schedule a follow-up call next Tuesday or Wednesday to walk through the integration steps?\n\nThanks,\nBen",
    "intent": "Meeting Request",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Question about custom reports\n\nHi Sales Team,\n\nDoes the Starlight Platform support creating custom, shareable reports? This is a key feature for us. Looking forward to your response.\n\nBest,\nLisa",
    "intent": "Sales Inquiry",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Reminder: Office Maintenance this Weekend\n\nHello Team,\n\nThis is a reminder that the office will be closed this Saturday for scheduled maintenance on the HVAC system. Please plan accordingly.\n\nThanks,\nOffice Management",
    "intent": "Internal Update",
    "urgency": "Low"
  },
  {
    "email_text": "Subject: Issue with user permissions\n\nHi Support Team,\n\nI'm trying to add a new user to our account with 'viewer' permissions, but I keep getting an error message. Can you help me figure out what's wrong?\n\nThanks,\nChris",
    "intent": "Technical Support",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Coffee Chat?\n\nHi Emily,\n\nI'd love to pick your brain about the new UX designs for the dashboard. Do you have 20 minutes for a virtual coffee chat sometime next week?\n\nBest,\nNew Product Manager",
    "intent": "Meeting Request",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Starlight Platform Trial Request\n\nHello,\n\nMy team would like to start a 14-day trial of your platform. How do we get started?\n\nThank you,\nSamantha",
    "intent": "Sales Inquiry",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Slow API Response Times\n\nSupport Team,\n\nWe've been noticing that API response times for the `/analytics` endpoint have been degraded for the past 24 hours, sometimes taking over 5 seconds. It's impacting user experience but not a full outage.\n\nRegards,\nDevOps Team",
    "intent": "Technical Support",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Holiday Schedule Announcement\n\nHi Everyone,\n\nJust a reminder that the company will be closed next Monday in observance of Labor Day. Enjoy the long weekend!\n\nCheers,\nHR",
    "intent": "Internal Update",
    "urgency": "Low"
  },
  {
    "email_text": "Subject: URGENT: Security Vulnerability Report\n\nTo the OrbitAI Security Team,\n\nWe believe we have discovered a potential XSS vulnerability in your platform's login page. This is a critical security issue. Please provide a secure channel for us to disclose the details.\n\n- White Hat Security Researcher",
    "intent": "Technical Support",
    "urgency": "High"
  },
  {
    "email_text": "Subject: Brainstorm Session: Q4 Marketing Campaign\n\nHi Marketing,\n\nLet's schedule a 1-hour brainstorm session for the Q4 campaign. Please fill out the when2meet link to find the best time for everyone.\n\nThanks,\nCMO",
    "intent": "Meeting Request",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Question about data sources\n\nHi there,\n\nCan the Starlight platform integrate with social media data sources like Twitter and Facebook? This is a key requirement for our team.\n\nThanks,\nAnalyst",
    "intent": "Sales Inquiry",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: New Wiki Page for Project Nova\n\nTeam,\n\nI've created a new Confluence page that will serve as the single source of truth for all Project Nova documentation. You can find the link here: [link].\n\nBest,\nSarah",
    "intent": "Internal Update",
    "urgency": "Low"
  },
  {
    "email_text": "Subject: Help with data export feature\n\nHi Support,\n\nI'm trying to export a report to CSV, but the file is coming out corrupted and unreadable. Can you please investigate?\n\nThank you,\nCustomer",
    "intent": "Technical Support",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Urgent: Final review before client presentation Friday\n\nHi team,\n\nWe need to schedule a final 1-hour review of the client presentation deck. This must happen before our big meeting on Friday morning. Please clear your calendars.\n\nRegards,\nAccount Manager",
    "intent": "Meeting Request",
    "urgency": "High"
  },
  {
    "email_text": "Subject: Enterprise License Inquiry\n\nHello,\n\nWe are a Fortune 500 company interested in purchasing an enterprise-wide license for the Starlight Platform. We would require a dedicated account manager and premium support. Could you connect us with the appropriate sales director?\n\nBest,\nVP of Technology",
    "intent": "Sales Inquiry",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: All-Hands Meeting Next Wednesday\n\nHi OrbitAI Team,\n\nOur quarterly All-Hands meeting is scheduled for next Wednesday at 1 PM CDT. The CEO will be sharing our Q3 results and our vision for Q4. Please be sure to attend.\n\nThanks,\nExecutive Assistant",
    "intent": "Internal Update",
    "urgency": "Low"
  },
  {
    "email_text": "Subject: Production Outage - User Login Failing\n\nSUPPORT - URGENT\n\nNone of our users are able to log in to the platform. We are getting a generic 'Authentication Failed' error. This is a complete outage for our entire user base. We need an update in the next 15 minutes.\n\n- CTO",
    "intent": "Technical Support",
    "urgency": "High"
  },
  {
    "email_text": "Subject: Request for Quote - 100 seats\n\nHi Sales,\n\nPlease provide an official quote for 100 user seats on your Professional plan. We are looking to make a purchasing decision by the end of the month.\n\nThank you,\nIT Procurement",
    "intent": "Sales Inquiry",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Quick chat about API documentation\n\nHi David,\n\nI had a few thoughts on how we could improve the API documentation for new users. Do you have 20 minutes to chat this week?\n\nThanks,\nTechnical Writer",
    "intent": "Meeting Request",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Typo in your documentation\n\nHi,\n\nJust a heads up, I found a small typo in your API documentation for the `/reports` endpoint. The parameter is listed as `report_ID` but it should be `report_id`. Not a big deal, just wanted to let you know!\n\nCheers,\nA Developer",
    "intent": "Technical Support",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: New Coffee Machine in the Breakroom!\n\nHi everyone,\n\nGreat news! The new espresso machine has been installed in the main breakroom. Please feel free to use it and enjoy!\n\nBest,\nOffice Management",
    "intent": "Internal Update",
    "urgency": "Low"
  },
  {
    "email_text": "Subject: Can we move our 1:1?\n\nHi Sarah,\n\nSomething came up and I need to reschedule our 1:1 meeting for this afternoon. Would sometime tomorrow morning work instead?\n\nSorry for the last-minute change,\nDavid",
    "intent": "Meeting Request",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Data not refreshing on dashboard\n\nHello Support,\n\nThe data on our main dashboard seems to be stale. The 'Last Updated' timestamp shows yesterday's date, and no new information is appearing. This is impacting our daily reporting.\n\nThanks,\nData Analyst",
    "intent": "Technical Support",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Security and Compliance Information Request\n\nHello,\n\nAs part of our vendor review process, we need you to provide your SOC 2 Type II report and any other relevant security and compliance documentation. Can you please direct me to the right person?\n\nRegards,\nCompliance Officer",
    "intent": "Sales Inquiry",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: URGENT: Billing System Error - Double Charged\n\nHi Support,\n\nOur company credit card was just charged twice for our monthly subscription. This is a critical issue that needs to be resolved immediately. Please reverse the duplicate charge and confirm.\n\nThanks,\nFinance Department",
    "intent": "Technical Support",
    "urgency": "High"
  },
  {
    "email_text": "Subject: Project Nova Design Review\n\nHi Emily,\n\nCan we schedule a 1-hour design review for the Project Nova mockups with the product team? I'd like to get their feedback before we move to high-fidelity prototypes.\n\nBest,\nSarah",
    "intent": "Meeting Request",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: New IT Ticketing System\n\nHi Team,\n\nStarting next Monday, we will be using a new IT ticketing system to handle all support requests. Please use the new portal for any IT issues. An email with login instructions will be sent out on Friday.\n\nThanks,\nIT Department",
    "intent": "Internal Update",
    "urgency": "Low"
  },
  {
    "email_text": "Subject: Is there an on-premise option?\n\nHi OrbitAI Sales,\n\nDue to our company's data privacy policies, we can only use on-premise software. Do you offer a version of the Starlight Platform that we can host on our own servers?\n\nThank you,\nCIO",
    "intent": "Sales Inquiry",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Unable to reset my password\n\nHello,\n\nI'm trying to reset my password using the 'Forgot Password' link, but I'm not receiving the reset email. I've checked my spam folder. Can you please assist?\n\nThanks,\nA User",
    "intent": "Technical Support",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Final Interview Scheduling\n\nHi Candidate,\n\nWe'd like to invite you for a final round of interviews. Please let us know your availability for a 2-hour block next week.\n\nBest,\nRecruiting",
    "intent": "Meeting Request",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: PTO Policy Update\n\nHello Everyone,\n\nThis email is to inform you of an update to our Paid Time Off policy, effective September 1st. Please review the attached document for details.\n\nRegards,\nHR",
    "intent": "Internal Update",
    "urgency": "Low"
  },
  {
    "email_text": "Subject: Question about SLA\n\nHi Sales Team,\n\nWhat is the Service Level Agreement (SLA) for your Enterprise plan? We need to know the guaranteed uptime and support response times.\n\nThanks,\nLegal Team",
    "intent": "Sales Inquiry",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: CRITICAL: Entire Platform Unresponsive\n\nSUPPORT - SEV1\n\nThe entire Starlight Platform is down. We are getting a 500 error on the login page and all API calls are failing. This is a major outage affecting all our operations. We need an immediate response and an ETA for a fix.\n\n- Head of Engineering",
    "intent": "Technical Support",
    "urgency": "High"
  },
  {
    "email_text": "Subject: Post-mortem meeting for yesterday's outage\n\nHi Engineering Team,\n\nWe need to schedule a mandatory post-mortem meeting to discuss the root cause of yesterday's platform outage. Please keep your calendars open for tomorrow afternoon.\n\nThanks,\nCTO",
    "intent": "Meeting Request",
    "urgency": "High"
  },
  {
    "email_text": "Subject: Welcome to the Team!\n\nHi Sarah,\n\nWelcome to OrbitAI! We are so excited to have you join us as our new Project Manager. Your first week's schedule is attached. Your laptop and swag are waiting for you at your desk.\n\nBest,\nYour Manager",
    "intent": "Internal Update",
    "urgency": "Low"
  },
  {
    "email_text": "Subject: Integration with Salesforce\n\nHi Support,\n\nI'm trying to set up the Salesforce integration, but I'm getting an authentication error. I've followed the documentation, but it's not working. Can you help?\n\nThanks,\nSales Ops",
    "intent": "Technical Support",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Non-profit discount?\n\nHello,\n\nWe are a registered non-profit organization and are very interested in your platform. Do you offer any discounts for non-profits?\n\nSincerely,\nExecutive Director",
    "intent": "Sales Inquiry",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Project Nova: Sprint Planning Meeting\n\nHi Project Nova Team,\n\nOur sprint planning meeting for the next two-week sprint is scheduled for this Monday at 10 AM. Please come prepared to discuss your priorities.\n\nThanks,\nSarah",
    "intent": "Meeting Request",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: Incorrect data in weekly report\n\nHi,\n\nThe automated weekly report that was just sent out appears to have incorrect data for our 'User Engagement' metric. The numbers are significantly lower than expected. Can you please re-run the report?\n\nThanks,\nMarketing Analyst",
    "intent": "Technical Support",
    "urgency": "Medium"
  },
  {
    "email_text": "Subject: End of Quarter Town Hall\n\nHi Team,\n\nThe End of Quarter Town Hall is next Friday. We'll be celebrating our wins and discussing our goals for the next quarter. Lunch will be provided!\n\nSee you there,\nLeadership Team",
    "intent": "Internal Update",
    "urgency": "Low"
  }
]
"""

# Save the text to a file
file_path = 'training_data.json'
with open(file_path, 'w', encoding='utf-8') as f:
    f.write(training_data_json)

print(f"File '{file_path}' saved successfully.")
# Out:
# File 'training_data.json' saved successfully.

# %%
import pandas as pd 
#loading the json file into pandas data frame
df = pd.read_json('training_data.json')
# display thre first 5 rows of data 
df.head()
# Out:
#                                           email_text             intent  \
# 0  Subject: Inquiry about Starlight Platform Pric...      Sales Inquiry
# 1  Subject: URGENT: API Gateway is Down!\r\n\r\nH...  Technical Support
# 2  Subject: Request for a Demo\r\n\r\nHi OrbitAI ...      Sales Inquiry
# 3  Subject: Quick Question: Project Nova Sync\r\n...    Meeting Request
# 4  Subject: Company Update: Welcome Our New Hires...    Internal Update
#
#   urgency
# 0  Medium
# 1    High
# 2  Medium
# 3  Medium
# 4     Low

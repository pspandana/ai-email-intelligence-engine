# %%
import pandas as pd 
#loading the json file into pandas data frame
df = pd.read_json('training_data.json')
# display thre first 5 rows of data 
df.head()
# Out:
#                                           email_text             intent  \
# 0  Subject: Inquiry about Starlight Platform Pric...      Sales Inquiry
# 1  Subject: URGENT: API Gateway is Down!\n\nHello...  Technical Support
# 2  Subject: Request for a Demo\n\nHi OrbitAI Sale...      Sales Inquiry
# 3  Subject: Quick Question: Project Nova Sync\n\n...    Meeting Request
# 4  Subject: Company Update: Welcome Our New Hires...    Internal Update
#
#   urgency
# 0  Medium
# 1    High
# 2  Medium
# 3  Medium
# 4     Low

# %%
from sklearn.model_selection import train_test_split
from datasets import Dataset
import pandas as pd

# Load the data again just in case
df = pd.read_json('training_data.json')

# 1. Create a single target label
df['label_str'] = df['intent'] + '_' + df['urgency']
labels = df['label_str'].unique().tolist()
label2id = {label: i for i, label in enumerate(labels)}
id2label = {i: label for i, label in enumerate(labels)}
df['label'] = df['label_str'].map(label2id)

# 2. Split the data into training and testing sets
train_df, test_df = train_test_split(df, test_size=0.2, random_state=42, stratify=df['label'])

# 3. Convert pandas DataFrames to Hugging Face Datasets
train_dataset = Dataset.from_pandas(train_df)
test_dataset = Dataset.from_pandas(test_df)

print("Data has been split and converted.")
print(f"Labels: {labels}")
# Out:
# Data has been split and converted.
# Labels: ['Sales Inquiry_Medium', 'Technical Support_High', 'Meeting Request_Medium', 'Internal Update_Low', 'Technical Support_Medium', 'Meeting Request_High']

# %%
df.sample(25)
# Out:
#                                            email_text             intent  \
# 77  Subject: New Referral Program!\n\nHi All,\n\nW...    Internal Update
# 11  Subject: Question about custom reports\n\nHi S...      Sales Inquiry
# 98  Subject: CRITICAL - Payment processing failed\...  Technical Support
# 57  Subject: Request for Proposal (RFP) - Analytic...      Sales Inquiry
# 29  Subject: Typo in your documentation\n\nHi,\n\n...  Technical Support
# 12  Subject: Reminder: Office Maintenance this Wee...    Internal Update
# 89  Subject: Coffee Chat?\n\nHi [Colleague Name],\...    Meeting Request
# 24  Subject: Enterprise License Inquiry\n\nHello,\...      Sales Inquiry
# 46  Subject: Non-profit discount?\n\nHello,\n\nWe ...      Sales Inquiry
# 88  Subject: Unable to add new team members\n\nHi ...  Technical Support
# 61  Subject: Follow-up on Enterprise Pricing\n\nHi...      Sales Inquiry
# 93  Subject: Reschedule - Project Nova Standup\n\n...    Meeting Request
# 80  Subject: Urgent: Security Patch Review - Deadl...    Meeting Request
# 58  Subject: Design Sync for Nova Dashboard\n\nHi ...    Meeting Request
# 73  Subject: IT System Maintenance Tonight\n\nHi T...    Internal Update
# 50  Subject: Onboarding Documentation for Starligh...  Technical Support
# 72  Subject: Incorrect data in analytics report\n\...  Technical Support
# 64  Subject: Company Offsite Announcement!\n\nTeam...    Internal Update
# 39  Subject: Final Interview Scheduling\n\nHi Cand...    Meeting Request
# 20  Subject: Question about data sources\n\nHi the...      Sales Inquiry
# 59  Subject: CRITICAL: Data Breach Detected\n\nSEC...  Technical Support
# 37  Subject: Is there an on-premise option?\n\nHi ...      Sales Inquiry
# 28  Subject: Quick chat about API documentation\n\...    Meeting Request
# 22  Subject: Help with data export feature\n\nHi S...  Technical Support
# 7   Subject: Partnership Opportunity\n\nHello Orbi...      Sales Inquiry
#
#    urgency                 label_str  label
# 77     Low       Internal Update_Low      3
# 11  Medium      Sales Inquiry_Medium      0
# 98    High    Technical Support_High      1
# 57  Medium      Sales Inquiry_Medium      0
# 29  Medium  Technical Support_Medium      4
# 12     Low       Internal Update_Low      3
# 89  Medium    Meeting Request_Medium      2
# 24  Medium      Sales Inquiry_Medium      0
# 46  Medium      Sales Inquiry_Medium      0
# 88  Medium  Technical Support_Medium      4
# 61  Medium      Sales Inquiry_Medium      0
# 93  Medium    Meeting Request_Medium      2
# 80    High      Meeting Request_High      5
# 58  Medium    Meeting Request_Medium      2
# 73     Low       Internal Update_Low      3
# 50  Medium  Technical Support_Medium      4
# 72  Medium  Technical Support_Medium      4
# 64     Low       Internal Update_Low      3
# 39  Medium    Meeting Request_Medium      2
# 20  Medium      Sales Inquiry_Medium      0
# 59    High    Technical Support_High      1
# 37  Medium      Sales Inquiry_Medium      0
# 28  Medium    Meeting Request_Medium      2
# 22  Medium  Technical Support_Medium      4
# 7   Medium      Sales Inquiry_Medium      0

# %%
print(label2id, "\n")
# Out:
# {'Sales Inquiry_Medium': 0, 'Technical Support_High': 1, 'Meeting Request_Medium': 2, 'Internal Update_Low': 3, 'Technical Support_Medium': 4, 'Meeting Request_High': 5}

# %%
from transformers import AutoTokenizer

# Load the tokenizer for DistilBERT
tokenizer = AutoTokenizer.from_pretrained('distilbert-base-uncased')

# Create a function to tokenize the text
def tokenize_function(examples):
    return tokenizer(examples['email_text'], padding='max_length', truncation=True)

# Apply the tokenization to our datasets
tokenized_train_dataset = train_dataset.map(tokenize_function, batched=True)
tokenized_test_dataset = test_dataset.map(tokenize_function, batched=True)

print("Tokenization complete.")
# Out:
# Map:   0%|          | 0/80 [00:00<?, ? examples/s]
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Tokenization complete.

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

# 1. Load the pre-trained DistilBERT model
model = AutoModelForSequenceClassification.from_pretrained(
    'distilbert-base-uncased', 
    num_labels=len(labels),
    id2label=id2label,
    label2id=label2id
)

# 2. Define the training arguments
training_args = TrainingArguments(
    output_dir='./results',          # Directory to save the results
    num_train_epochs=3,              # We'll train for 3 full passes over the data
    per_device_train_batch_size=8,   # Process 8 examples at a time during training
    per_device_eval_batch_size=8,    # Process 8 examples at a time during evaluation
    warmup_steps=500,                # Number of steps to warm up the learning rate
    weight_decay=0.01,               # Strength of weight decay
    logging_dir='./logs',            # Directory for storing logs
    logging_steps=10,
)

# 3. Create the Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_train_dataset,
    eval_dataset=tokenized_test_dataset,
)

# 4. Start the training
trainer.train()

print("Training complete.")

# 5. Save the final model
trainer.save_model('./models/triage_classifier', safe_serialization=False)
tokenizer.save_pretrained('./models/triage_classifier')

print("Model saved to './models/triage_classifier'")
# Out:
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# c:\Users\saira\Documents\email_intelligence_engine\myvenv\Lib\site-packages\torch\utils\data\dataloader.py:666: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
#     <div>
#
#       <progress value='30' max='30' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [30/30 02:15, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.802000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.790100</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.783700</td>
#     </tr>
#   </tbody>
# </table><p>
# Training complete.
# ---------------------------------------------------------------------------
# SafetensorError                           Traceback (most recent call last)
# Cell In[6], line 37
#      34 print("Training complete.")
#      36 # 5. Save the final model
# ---> 37 trainer.save_model('./models/triage_classifier')
#      38 tokenizer.save_pretrained('./models/triage_classifier')
#      40 print("Model saved to './models/triage_classifier'")
#
# File c:\Users\saira\Documents\email_intelligence_engine\myvenv\Lib\site-packages\transformers\trainer.py:3992, in Trainer.save_model(self, output_dir, _internal_call)
#    3989         self.model_wrapped.save_checkpoint(output_dir)
#    3991 elif self.args.should_save:
# -> 3992     self._save(output_dir)
#    3994 # Push to the Hub when `save_model` is called by the user.
#    3995 if self.args.push_to_hub and not _internal_call:
#
# File c:\Users\saira\Documents\email_intelligence_engine\myvenv\Lib\site-packages\transformers\trainer.py:4096, in Trainer._save(self, output_dir, state_dict)
#    4094             torch.save(state_dict, os.path.join(output_dir, WEIGHTS_NAME))
#    4095 else:
# -> 4096     self.model.save_pretrained(
#    4097         output_dir, state_dict=state_dict, safe_serialization=self.args.save_safetensors
#    4098     )
#    4100 if self.processing_class is not None:
#    4101     self.processing_class.save_pretrained(output_dir)
#
# File c:\Users\saira\Documents\email_intelligence_engine\myvenv\Lib\site-packages\transformers\modeling_utils.py:4172, in PreTrainedModel.save_pretrained(self, save_directory, is_main_process, state_dict, save_function, push_to_hub, max_shard_size, safe_serialization, variant, token, save_peft_format, **kwargs)
#    4167     gc.collect()
#    4169 if safe_serialization:
#    4170     # At some point we will need to deal better with save_function (used for TPU and other distributed
#    4171     # joyfulness), but for now this enough.
# -> 4172     safe_save_file(shard, os.path.join(save_directory, shard_file), metadata={"format": "pt"})
#    4173 else:
#    4174     save_function(shard, os.path.join(save_directory, shard_file))
#
# File c:\Users\saira\Documents\email_intelligence_engine\myvenv\Lib\site-packages\safetensors\torch.py:352, in save_file(tensors, filename, metadata)
#     321 def save_file(
#     322     tensors: Dict[str, torch.Tensor],
#     323     filename: Union[str, os.PathLike],
#     324     metadata: Optional[Dict[str, str]] = None,
#     325 ):
#     326     """
#     327     Saves a dictionary of tensors into raw bytes in safetensors format.
#     328
#    (...)    350     ```
#     351     """
# --> 352     serialize_file(_flatten(tensors), filename, metadata=metadata)
#
# SafetensorError: Error while serializing: I/O error: The requested operation cannot be performed on a file with a user-mapped section open. (os error 1224)

# %%
# %pip install accelerate>=0.26.0
# Out:
# Note: you may need to restart the kernel to use updated packages.
